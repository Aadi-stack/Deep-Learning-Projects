# %% [markdown]
# <a href="https://colab.research.google.com/github/aaditshukla98710/Deep-Learning-Projects/blob/main/Convert_Image_RGB_into_Grayscale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd  
import tensorflow as tf 
import seaborn  as sns  
import matplotlib.pyplot as plt
from tensorflow.keras import models,layers

# %%
# getting an image using web get

# !wget 'https://cdn5.vectorstock.com/i/1000x1000/47/84/colored-mask-superhero-batman-vector-12994784.jpg'
# Out:
# --2023-04-19 06:03:16--  https://cdn5.vectorstock.com/i/1000x1000/47/84/colored-mask-superhero-batman-vector-12994784.jpg
# Resolving cdn5.vectorstock.com (cdn5.vectorstock.com)... 192.229.163.147
# Connecting to cdn5.vectorstock.com (cdn5.vectorstock.com)|192.229.163.147|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 143967 (141K) [image/jpeg]
# Saving to: ‘colored-mask-superhero-batman-vector-12994784.jpg’
#
# colored-mask-superh 100%[===================>] 140.59K  --.-KB/s    in 0.03s
#
# 2023-04-19 06:03:16 (4.30 MB/s) - ‘colored-mask-superhero-batman-vector-12994784.jpg’ saved [143967/143967]

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
image=mpimg.imread('/content/Batman .jpg')

# %%
image
# Out:
# array([[[235, 135, 195],
#         [235, 135, 195],
#         [235, 135, 195],
#         ...,
#         [132, 208, 224],
#         [132, 208, 224],
#         [132, 208, 224]],
#
#        [[235, 135, 195],
#         [235, 135, 195],
#         [235, 135, 195],
#         ...,
#         [132, 208, 224],
#         [132, 208, 224],
#         [132, 208, 224]],
#
#        [[235, 135, 195],
#         [235, 135, 195],
#         [235, 135, 195],
#         ...,
#         [132, 208, 224],
#         [132, 208, 224],
#         [132, 208, 224]],
#
#        ...,
#
#        [[ 17,  18,  36],
#         [ 17,  18,  36],
#         [ 17,  18,  36],
#         ...,
#         [ 17,  18,  36],
#         [ 17,  18,  36],
#         [ 17,  18,  36]],
#
#        [[ 17,  18,  36],
#         [ 17,  18,  36],
#         [ 17,  18,  36],
#         ...,
#         [ 17,  18,  36],
#         [ 17,  18,  36],
#         [ 17,  18,  36]],
#
#        [[ 17,  18,  36],
#         [ 17,  18,  36],
#         [ 17,  18,  36],
#         ...,
#         [ 17,  18,  36],
#         [ 17,  18,  36],
#         [ 17,  18,  36]]], dtype=uint8)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
print(image.shape)
# Out:
# (1080, 1000, 3)

# %%
print(image)
# Out:
# [[[235 135 195]
#   [235 135 195]
#   [235 135 195]
#   ...
#   [132 208 224]
#   [132 208 224]
#   [132 208 224]]
#
#  [[235 135 195]
#   [235 135 195]
#   [235 135 195]
#   ...
#   [132 208 224]
#   [132 208 224]
#   [132 208 224]]
#
#  [[235 135 195]
#   [235 135 195]
#   [235 135 195]
#   ...
#   [132 208 224]
#   [132 208 224]
#   [132 208 224]]
#
#  ...
#
#  [[ 17  18  36]
#   [ 17  18  36]
#   [ 17  18  36]
#   ...
#   [ 17  18  36]
#   [ 17  18  36]
#   [ 17  18  36]]
#
#  [[ 17  18  36]
#   [ 17  18  36]
#   [ 17  18  36]
#   ...
#   [ 17  18  36]
#   [ 17  18  36]
#   [ 17  18  36]]
#
#  [[ 17  18  36]
#   [ 17  18  36]
#   [ 17  18  36]
#   ...
#   [ 17  18  36]
#   [ 17  18  36]
#   [ 17  18  36]]]

# %%
# displaying the image from numpy array

img_plot = plt.imshow(image)
plt.show()

# %%
from PIL import Image

# %%
img = Image.open('/content/Batman .jpg')
img_resized = img.resize((200, 200))

# %%
img_resized
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FD6B4B47310>

# %%
img_resized.save('dog_image_resized.jpg')

# %%
img_res = mpimg.imread('/content/dog_image_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %%
import cv2

# %%
img=cv2.imread('/content/Batman .jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1080, 1000, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
grayscale_image
# Out:
# array([[164, 164, 164, ..., 204, 204, 204],
#        [164, 164, 164, ..., 204, 204, 204],
#        [164, 164, 164, ..., 204, 204, 204],
#        ...,
#        [ 23,  23,  23, ...,  23,  23,  23],
#        [ 23,  23,  23, ...,  23,  23,  23],
#        [ 23,  23,  23, ...,  23,  23,  23]], dtype=uint8)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (1080, 1000)

# %%
from google.colab.patches import cv2_imshow

# %%
# displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=1000x1080 at 0x7FD6A595A610>
